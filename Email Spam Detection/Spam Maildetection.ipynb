# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the data from csv file to a pandas Dataframe
raw_mail_data = pd.read_csv('/content/mail_data.csv')

# %%
print(raw_mail_data)
# Out:
#      Category                                            Message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
# replace the null values with a null string
mail_data = raw_mail_data.where((pd.notnull(raw_mail_data)),'')

# %%
# printing the first 5 rows of the dataframe
mail_data.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
# checking the number of rows and columns in the dataframe
mail_data.shape
# Out:
# (5572, 2)

# %% [markdown]
# Label Encoding

# %%
# label spam mail as 0;  ham mail as 1;

mail_data.loc[mail_data['Category'] == 'spam', 'Category',] = 0
mail_data.loc[mail_data['Category'] == 'ham', 'Category',] = 1

# %% [markdown]
# spam - 0
#
# ham - 1

# %%
# separating the data as texts and label

X = mail_data['Message']

Y = mail_data['Category']

# %%
# Assuming 'mail_data' is a pandas DataFrame and has been loaded correctly
X = mail_data['Message']  # Assign 'Message' column to X

print(X)  # Now you can print X
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                 Will ü b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: Message, Length: 5572, dtype: object

# %%
print(Y)
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 5567    0
# 5568    1
# 5569    1
# 5570    1
# 5571    1
# Name: Category, Length: 5572, dtype: object

# %% [markdown]
# Solitting the Data into training data & data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=3)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (5572,)
# (4457,)
# (1115,)

# %% [markdown]
# Feature Extraction

# %%
# transform the text data to feature vectors that can be used as input to the Logistic regression

feature_extraction = TfidfVectorizer(min_df = 1, stop_words='english', lowercase=True) # Changed 'True' to True

# Convert each list of tokens into a single string
X_train_flattened = [' '.join(doc) for doc in X_train]
X_test_flattened = [' '.join(doc) for doc in X_test]


# convert Y_train and Y_test values as integers

Y_train = Y_train.astype('int')
Y_test = Y_test.astype('int')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-f7b53142a140> in <cell line: 6>()
#       4
#       5 # Convert each list of tokens into a single string
# ----> 6 X_train_flattened = [' '.join(doc) for doc in X_train]
#       7 X_test_flattened = [' '.join(doc) for doc in X_test]
#       8
#
# <ipython-input-54-f7b53142a140> in <listcomp>(.0)
#       4
#       5 # Convert each list of tokens into a single string
# ----> 6 X_train_flattened = [' '.join(doc) for doc in X_train]
#       7 X_test_flattened = [' '.join(doc) for doc in X_test]
#       8
#
# TypeError: sequence item 0: expected str instance, int found

# %%
print(type(X_train))  # Should be <class 'list'>
print(type(X_train[0]))  # Should be <class 'str'> if each element is a string
print(X_train[:2])  # Print a few samples to verify format
# Out:
# <class 'list'>
# <class 'list'>
# [[3, 4], [1, 2]]

# %%
print(X_train_features)
# Out:
#   (0, 2)	0.5797386715376657
#   (0, 1)	0.8148024746671689
#   (1, 0)	0.8148024746671689
#   (1, 2)	0.5797386715376657

# %% [markdown]
# Training the Model

# %%
model = LogisticRegression()

# %%
# Check the shapes of X_train_features and Y_train
print(f"Shape of X_train_features: {X_train_features.shape}")
print(f"Shape of Y_train: {len(Y_train)}")

# Ensure both have the same number of samples. If not, investigate data processing steps.
# If X_train_features is a DataFrame, use shape[0]
# If X_train_features is a numpy array use shape[0]
# If X_train_features is a list use len(X_train_features)


# After fixing the data shapes, try fitting the model again
model.fit(X_train_features, Y_train)
# Out:
# Shape of X_train_features: (2, 3)
# Shape of Y_train: 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-daa6de15e046> in <cell line: 12>()
#      10
#      11 # After fixing the data shapes, try fitting the model again
# ---> 12 model.fit(X_train_features, Y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1206             _dtype = [np.float64, np.float32]
#    1207
# -> 1208         X, y = self._validate_data(
#    1209             X,
#    1210             y,
#
# ...

# %% [markdown]
# Evaluting the trained model

# %%
# prediction on training data

prediction_on_training_data = model.predict(X_train_features)
accuracy_on_training_data = accuracy_score(Y_train, prediction_on_training_data)

# %%
print('Accuracy on training data : ', accuracy_on_training_data)
# Out:
# Accuracy on training data :  0.9670181736594121

# %%
# prediction on test data

prediction_on_test_data = model.predict(X_test_features)
accuracy_on_test_data = accuracy_score(Y_test, prediction_on_test_data)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-49-517e2f5c23ca> in <cell line: 3>()
#       1 # prediction on test data
#       2
# ----> 3 prediction_on_test_data = model.predict(X_test_features)
#       4 accuracy_on_test_data = accuracy_score(Y_test, prediction_on_test_data)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     449         """
#     450         xp, _ = get_namespace(X)
# --> 451         scores = self.decision_function(X)
#     452         if len(scores.shape) == 1:
#     453             indices = xp.astype(scores > 0, int)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     427             this class would be predicted.
#     428         """
# --> 429         check_is_fitted(self)
#     430         xp, _ = get_namespace(X)
#     431
#
# ...

# %%
print('Accuracy on test data : ', accuracy_on_test_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-e1d8609fbea4> in <cell line: 1>()
# ----> 1 print('Accuracy on test data : ', accuracy_on_test_data)
#
# NameError: name 'accuracy_on_test_data' is not defined

# %% [markdown]
# Building a Predictive System

# %%
# convert text to feature vectors

# %%
input_mail = ["I've been searching for the right words to thank you for this breather. I promise i wont take your help for granted and will fulfil my promise. You have been wonderful and a blessing at all times"]

# convert text to feature vectors
input_data_features = feature_extraction.transform(input_mail)

# making prediction

prediction = model.predict(input_data_features)
print(prediction)


if (prediction[0]==1):
  print('Ham mail')

else:
  print('Spam mail')
# Out:
# [1]
# Ham mail
